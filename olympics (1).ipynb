# %% [markdown]
#                                           Olympics Data set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Extract the data and store it in the variable `df`

# %%
df=pd.read_csv(r"C:\Users\melim\OneDrive\Desktop\eda projects\olymipics_dataset\olympics_dataset.csv")
df
# Out:
#         player_id                   Name Sex               Team  NOC  Year  \
# 0               0              A Dijiang   M              China  CHN  1992
# 1               1               A Lamusi   M              China  CHN  2012
# 2               2            Gunnar Aaby   M            Denmark  DEN  1920
# 3               3            Edgar Aabye   M     Denmark/Sweden  DEN  1900
# 4              26  Cornelia (-strannood)   F        Netherlands  NED  1932
# ...           ...                    ...  ..                ...  ...   ...
# 252560    4986655             Sefora Ada   F  Equatorial Guinea  GEQ  2024
# 252561    9460001        Emanuela Liuzzi   F              Italy  ITA  2024
# 252562    1972077           Isayah Boers   M        Netherlands  NED  2024
# 252563    1899865            Kevin Staut   M             France  FRA  2024
# 252564    1924402        Charlie Carvell   M      Great Britain  GBR  2024
#
# ...

# %% [markdown]
# 2.Determine the shape of the data set.

# %%
rows,columns=df.shape
print(f"rows = {rows}")
print(f"columns ={columns}")
# Out:
# rows = 252565
# columns =11

# %% [raw]
# 3. Display the first 10 records of the data set.

# %%
df.head(10)
# Out:
#    player_id                   Name Sex            Team  NOC  Year  Season  \
# 0          0              A Dijiang   M           China  CHN  1992  Summer
# 1          1               A Lamusi   M           China  CHN  2012  Summer
# 2          2            Gunnar Aaby   M         Denmark  DEN  1920  Summer
# 3          3            Edgar Aabye   M  Denmark/Sweden  DEN  1900  Summer
# 4         26  Cornelia (-strannood)   F     Netherlands  NED  1932  Summer
# 5         27  Cornelia (-strannood)   F     Netherlands  NED  1932  Summer
# 6         29            Einar Aalto   M         Finland  FIN  1952  Summer
# 7         31             Jyri Aalto   M         Finland  FIN  2000  Summer
# 8         32            Minna Aalto   F         Finland  FIN  1996  Summer
# 9         33            Minna Aalto   F         Finland  FIN  2000  Summer
#
#           City       Sport                                   Event     Medal
# ...

# %% [markdown]
# 4. Display the overview of the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252565 entries, 0 to 252564
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   player_id  252565 non-null  int64
#  1   Name       252565 non-null  object
#  2   Sex        252565 non-null  object
#  3   Team       252565 non-null  object
#  4   NOC        252565 non-null  object
#  5   Year       252565 non-null  int64
#  6   Season     252565 non-null  object
#  7   City       252565 non-null  object
#  8   Sport      252565 non-null  object
#  9   Event      252565 non-null  object
#  10  Medal      252565 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 21.2+ MB

# %% [markdown]
# 5. Determine the data types of each column in the dataset.

# %%
df.dtypes
# Out:
# player_id     int64
# Name         object
# Sex          object
# Team         object
# NOC          object
# Year          int64
# Season       object
# City         object
# Sport        object
# Event        object
# Medal        object
# dtype: object

# %% [markdown]
# 6. Check the given data set contains any null values. If it contains any null values handle
# them.

# %%
df.isnull().sum()
# Out:
# player_id    0
# Name         0
# Sex          0
# Team         0
# NOC          0
# Year         0
# Season       0
# City         0
# Sport        0
# Event        0
# Medal        0
# dtype: int64

# %% [markdown]
# 7.Check the given data set contains any duplicate values or not. If it contains any
# duplicates handle them.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 8. Find and Visualize the count of the medal type by the male players

# %%
male=df[df['Sex']=='M']
gmale=male.groupby('Medal')['Sex'].count()
plt.figure(figsize=(10,8))
gmale.plot(kind='bar',color=['r','g','y','m'])
plt.xlabel('Medals')
plt.ylabel('No of medals by males')
plt.title("Count of medal type by the male playes")
plt.show()

# %%
df[df['Sex']=='M']
# Out:
#         player_id                 Name Sex                 Team  NOC  Year  \
# 0               0            A Dijiang   M                China  CHN  1992
# 1               1             A Lamusi   M                China  CHN  2012
# 2               2          Gunnar Aaby   M              Denmark  DEN  1920
# 3               3          Edgar Aabye   M       Denmark/Sweden  DEN  1900
# 6              29          Einar Aalto   M              Finland  FIN  1952
# ...           ...                  ...  ..                  ...  ...   ...
# 252555    4979790  Steven Insixiengmay   M              Lao PDR  LAO  2024
# 252557    4982175        Elijah Joseph   M  Trinidad and Tobago  TTO  2024
# 252562    1972077         Isayah Boers   M          Netherlands  NED  2024
# 252563    1899865          Kevin Staut   M               France  FRA  2024
# 252564    1924402      Charlie Carvell   M        Great Britain  GBR  2024
#
# ...

# %% [markdown]
# 9. Find and Visualize the count of the medal type by the female players

# %%
Fmale=df[df['Sex']=='F']
gFmale=male.groupby('Medal')['Sex'].count()
plt.figure(figsize=(8,5))
gFmale.plot(kind='bar',color=['r','g','y','m'])
plt.xlabel('Medals')
plt.ylabel('No of medals by Females')
plt.title("Count of medal type by the Female playes")
plt.show()

# %% [markdown]
# 10. Find and Visualize the top 5 sports by the Men

# %%
male=df[df['Sex']=='M']
spo=male.groupby('Sport')['Sex'].count()
lar=spo.nlargest(5)
lar.plot(kind='pie',autopct='%0.1f%%',explode=[0.1,0,0,0,0],startangle=90)
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# 11.Find and Visualize the top 5 sports by the Female

# %%
Female=df[df['Sex']=='F']
spo=Female.groupby('Sport')['Sex'].count()
lar=spo.nlargest(5)
lar.plot(kind='pie',autopct='%0.1f%%',explode=[0.1,0,0,0,0],startangle=30)
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# 12. Visualize the total Medals Count for gold,silver,bronze

# %%
year=df.groupby(['Year','Medal']).size() 
filtered = year.loc[(slice(None), ['Gold', 'Silver', 'Bronze'])]
medal_counts = filtered.groupby('Medal').sum()
medal_counts.plot(kind='bar', color=['#cd7f32', 'gold', 'silver'])
plt.xlabel('Medal Type')
plt.ylabel('Count')
plt.title('Total Medal Counts for Gold, Silver, and Bronze')
plt.show()

# %% [markdown]
# 13. Visualize the top sports names mostly played by the players

# %%
most=df['Sport'].value_counts()
larg=most.nlargest(5)
plt.barh(larg.index, larg.values, color='skyblue')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 14. Find the top cities with the most players

# %%
city=df.groupby('City').size()
top=city.nlargest(10)
top.plot(kind='bar')
plt.xlabel('Cities')
plt.ylabel('Count of the players')
plt.title('Top 10 Cities with the Most Players')
plt.show()

# %% [markdown]
# 15. Visualize the year wise medal count from the given data

# %%
c=df.groupby('Year')['Medal'].size()
d=c.nlargest(10)
plt.plot(d.index,d.values,marker='<',color='pink',markerfacecolor='black')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.title('Top 10 Years with the Highest Medal Counts')
plt.xticks(rotation=45)
plt.tight_layout()  
plt.show()

# %% [markdown]
# 16. Find and Visualize the top 5 events in the any one year

# %%
sep=df[df['Year']==2024]
cou=sep.groupby('Event').size()
pcou=cou.nlargest(5)
pcou_df = pcou.reset_index(name='Count')
sns.barplot(y='Event',x='Count',data=pcou_df)
plt.title("Top 5 events in 2024 ") 
plt.show()

# %% [markdown]
# 17.Top players names who won more gold medals from the given data

# %%
gold=df[df['Medal']=='Gold']
sgold=gold.groupby('Name').size()
pgold=sgold.nlargest(5)
colors=['gold', 'lightgoldenrodyellow', 'khaki', 'palegoldenrod', 'lemonchiffon']
plt.pie(pgold, labels=pgold.index, autopct='%1.1f%%',colors=colors,explode=[0.1,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a3b84a0b50>,
# ...
#  [Text(0.452073480892915, 1.1115887584324355, 'Michael Ii'),
#   Text(-1.0637304914657988, 0.28013825430656647, 'Charles Jr.'),
#   Text(-0.7877674313025189, -0.767738545456089, 'Raymond Ewry'),
#   Text(0.19720880479386996, -1.0821777521792681, 'Caeleb Dressel'),
#   Text(0.9839357859225666, -0.49180318134487644, 'Frederick Lewis')],
#  [Text(0.26370953052086704, 0.6484267757522539, '37.7%'),
#   Text(-0.5802166317086174, 0.15280268416721804, '16.4%'),
#   Text(-0.4296913261650103, -0.41876647933968486, '16.4%'),
#   Text(0.10756843897847451, -0.5902787739159644, '14.8%'),
#   Text(0.5366922468668545, -0.26825628073356894, '14.8%')])

# %% [markdown]
# 18.Top players names who won more silver medals from the given data

# %%
silver=df[df['Medal']=='Silver']
ssilver=silver.groupby('Name').size()
psilver=ssilver.nlargest(5)
colors=['silver', 'lightgoldenrodyellow', 'khaki', 'palegoldenrod', 'lemonchiffon']
plt.pie(psilver, labels=psilver.index, autopct='%1.1f%%',colors=colors,explode=[0.1,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a3b8488b50>,
# ...
#  [Text(0.9105097637565587, 0.7816469600171012, 'Gustaf Carlberg'),
#   Text(-0.4844335070589577, 0.9875850227897135, 'Aleksandr Dityatin'),
#   Text(-1.0943562664864532, -0.11128504841995318, 'Duncan Scott'),
#   Text(-0.27571792699669956, -1.0648847941127917, 'Mikhail Voronin'),
#   Text(0.9028396790461523, -0.6283951893035473, 'Shirley Babashoff')],
#  [Text(0.5311306955246592, 0.45596072667664234, '22.6%'),
#   Text(-0.26423645839579507, 0.53868273970348, '19.4%'),
#   Text(-0.5969215999017017, -0.06070093550179264, '19.4%'),
#   Text(-0.1503915965436543, -0.5808462513342499, '19.4%'),
#   Text(0.4924580067524466, -0.34276101234738937, '19.4%')])

# %% [markdown]
# 19.Top players names who won more bronze medals from the given data

# %%
bronze=df[df['Medal']=='Bronze']
sbronze=bronze.groupby('Name').size()
pbronze=sbronze.nlargest(5)
colors=['brown', 'lightgoldenrodyellow', 'khaki', 'palegoldenrod', 'lemonchiffon']
plt.pie(psilver, labels=psilver.index, autopct='%1.1f%%',colors=colors,explode=[0.1,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a3b5085c50>,
# ...
#  [Text(0.9105097637565587, 0.7816469600171012, 'Gustaf Carlberg'),
#   Text(-0.4844335070589577, 0.9875850227897135, 'Aleksandr Dityatin'),
#   Text(-1.0943562664864532, -0.11128504841995318, 'Duncan Scott'),
#   Text(-0.27571792699669956, -1.0648847941127917, 'Mikhail Voronin'),
#   Text(0.9028396790461523, -0.6283951893035473, 'Shirley Babashoff')],
#  [Text(0.5311306955246592, 0.45596072667664234, '22.6%'),
#   Text(-0.26423645839579507, 0.53868273970348, '19.4%'),
#   Text(-0.5969215999017017, -0.06070093550179264, '19.4%'),
#   Text(-0.1503915965436543, -0.5808462513342499, '19.4%'),
#   Text(0.4924580067524466, -0.34276101234738937, '19.4%')])

# %% [markdown]
# 20. Find and Visualise Sports wise medal counts

# %%
medal_df = df[df['Medal'] != 'No medal']
sport_medal_counts = medal_df.groupby('Sport')['Medal'].count().reset_index()
sport_medal_counts = sport_medal_counts.sort_values(by='Medal', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='Sport', y='Medal', data=sport_medal_counts, palette='viridis')
plt.title('Sport-wise Medal Counts')
plt.xlabel('Sport')
plt.ylabel('Number of Medals')
plt.xticks(rotation=90)
plt.show()
